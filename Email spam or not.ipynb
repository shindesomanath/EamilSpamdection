# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\My Datasets\spam.csv",encoding='latin-1')

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 5567        NaN        NaN        NaN        NaN        NaN        NaN
# 5568        NaN        NaN        NaN        NaN        NaN        NaN
# 5569        NaN        NaN        NaN        NaN        NaN        NaN
# 5570        NaN        NaN        NaN        NaN        NaN        NaN
# 5571        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Unnamed: 9  ... Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 0           NaN  ...         NaN         NaN         NaN         NaN
# 1           NaN  ...         NaN         NaN         NaN         NaN
# 2           NaN  ...         NaN         NaN         NaN         NaN
# 3           NaN  ...         NaN         NaN         NaN         NaN
# 4           NaN  ...         NaN         NaN         NaN         NaN
# ...         ...  ...         ...         ...         ...         ...
# 5567        NaN  ...         NaN         NaN         NaN         NaN
# 5568        NaN  ...         NaN         NaN         NaN         NaN
# 5569        NaN  ...         NaN         NaN         NaN         NaN
# 5570        NaN  ...         NaN         NaN         NaN         NaN
# 5571        NaN  ...         NaN         NaN         NaN         NaN
#
#      Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 5567         NaN         NaN         NaN         NaN         NaN         NaN
# 5568         NaN         NaN         NaN         NaN         NaN         NaN
# 5569         NaN         NaN         NaN         NaN         NaN         NaN
# 5570         NaN         NaN         NaN         NaN         NaN         NaN
# 5571         NaN         NaN         NaN         NaN         NaN         NaN
#
# [5572 rows x 38 columns]

# %%
# Data cleaning 
# EDA
# Text preproccesing
# Evaluation
# Improvemant
# Website
# deplayA

# %% [markdown]
# # Data Cleaning

# %%
df.shape
# Out:
# (5572, 38)

# %%
df.info
# Out:
# <bound method DataFrame.info of         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 5567        NaN        NaN        NaN        NaN        NaN        NaN
# 5568        NaN        NaN        NaN        NaN        NaN        NaN
# 5569        NaN        NaN        NaN        NaN        NaN        NaN
# 5570        NaN        NaN        NaN        NaN        NaN        NaN
# 5571        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Unnamed: 9  ... Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 0           NaN  ...         NaN         NaN         NaN         NaN
# 1           NaN  ...         NaN         NaN         NaN         NaN
# 2           NaN  ...         NaN         NaN         NaN         NaN
# 3           NaN  ...         NaN         NaN         NaN         NaN
# 4           NaN  ...         NaN         NaN         NaN         NaN
# ...         ...  ...         ...         ...         ...         ...
# 5567        NaN  ...         NaN         NaN         NaN         NaN
# 5568        NaN  ...         NaN         NaN         NaN         NaN
# 5569        NaN  ...         NaN         NaN         NaN         NaN
# 5570        NaN  ...         NaN         NaN         NaN         NaN
# 5571        NaN  ...         NaN         NaN         NaN         NaN
#
#      Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 5567         NaN         NaN         NaN         NaN         NaN         NaN
# 5568         NaN         NaN         NaN         NaN         NaN         NaN
# 5569         NaN         NaN         NaN         NaN         NaN         NaN
# 5570         NaN         NaN         NaN         NaN         NaN         NaN
# 5571         NaN         NaN         NaN         NaN         NaN         NaN
#
# [5572 rows x 38 columns]>

# %%
df1=df[["v1","v2"]]

# %%
df1
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
#Renaming the columns
df1.rename(columns={'v1':"target","v2":"text"},inplace=True)
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_11740\547106308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'v1':"target","v2":"text"},inplace=True)

# %%
df1
# Out:
#      target                                               text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df1['target']=encoder.fit_transform(df1['target'])
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_11740\3059647179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['target']=encoder.fit_transform(df1['target'])

# %%
df1
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df1.isnull().sum()
# Out:
# target    0
# text      1
# dtype: int64

# %%
df1["text"]=df1["text"].fillna("Wait For me ")
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_11740\2030356844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["text"]=df1["text"].fillna("Wait For me ")

# %%
df1.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 408

# %%
df=df1.drop_duplicates(keep="first")

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5164, 2)

# %% [markdown]
# # EDA

# %%
df["target"].value_counts()
# Out:
# 0    4511
# 1     653
# Name: target, dtype: int64

# %%
plt.pie(df["target"].value_counts(),labels=["ham","spam"])
# Out:
# ([<matplotlib.patches.Wedge at 0x26d1a4d66a0>,
#   <matplotlib.patches.Wedge at 0x26d1a4d6b80>],
#  [Text(-1.0143361920592961, 0.42558440934630937, 'ham'),
#   Text(1.0143361522132035, -0.4255845043153158, 'spam')])

# %%
#Data is imbalanced

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\shind\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shind\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: click in c:\users\shind\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\shind\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\shind\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\shind\anaconda3\lib\site-packages (from click->nltk) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10054] An
# [nltk_data]     existing connection was forcibly closed by the remote
# [nltk_data]     host>
# False

# %%
df["num_char"]=df["text"].apply(len)
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_11740\2998575865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_char"]=df["text"].apply(len)

# %%
df
# Out:
#       target                                               text  num_char
# 0          0  Go until jurong point, crazy.. Available only ...       111
# 1          0                      Ok lar... Joking wif u oni...        29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3          0  U dun say so early hor... U c already then say...        49
# 4          0  Nah I don't think he goes to usf, he lives aro...        61
# ...      ...                                                ...       ...
# 5567       1  This is the 2nd time we have tried 2 contact u...       161
# 5568       0              Will Ì_ b going to esplanade fr home?        37
# 5569       0  Pity, * was in mood for that. So...any other s...        57
# 5570       0  The guy did some bitching but I acted like i'd...       125
# 5571       0                         Rofl. Its true to its name        26
#
# [5164 rows x 3 columns]

# %%
#num of words
df["text"].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# 0       24
# 1        8
# 2       37
# 3       13
# 4       15
#         ..
# 5567    35
# 5568     9
# 5569    15
# 5570    27
# 5571     7
# Name: text, Length: 5164, dtype: int64

# %%
df["num_word"]=df["text"].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_11740\3341324424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_word"]=df["text"].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df
# Out:
#       target                                               text  num_char  \
# 0          0  Go until jurong point, crazy.. Available only ...       111
# 1          0                      Ok lar... Joking wif u oni...        29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3          0  U dun say so early hor... U c already then say...        49
# 4          0  Nah I don't think he goes to usf, he lives aro...        61
# ...      ...                                                ...       ...
# 5567       1  This is the 2nd time we have tried 2 contact u...       161
# 5568       0              Will Ì_ b going to esplanade fr home?        37
# 5569       0  Pity, * was in mood for that. So...any other s...        57
# 5570       0  The guy did some bitching but I acted like i'd...       125
# 5571       0                         Rofl. Its true to its name        26
#
#       num_word
# 0           24
# 1            8
# 2           37
# 3           13
# 4           15
# ...        ...
# 5567        35
# 5568         9
# 5569        15
# 5570        27
# 5571         7
#
# [5164 rows x 4 columns]

# %%
df["num_sent"]=df["text"].apply(lambda x:len(nltk.sent_tokenize(x)))
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_11740\2206480495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_sent"]=df["text"].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df
# Out:
#       target                                               text  num_char  \
# 0          0  Go until jurong point, crazy.. Available only ...       111
# 1          0                      Ok lar... Joking wif u oni...        29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3          0  U dun say so early hor... U c already then say...        49
# 4          0  Nah I don't think he goes to usf, he lives aro...        61
# ...      ...                                                ...       ...
# 5567       1  This is the 2nd time we have tried 2 contact u...       161
# 5568       0              Will Ì_ b going to esplanade fr home?        37
# 5569       0  Pity, * was in mood for that. So...any other s...        57
# 5570       0  The guy did some bitching but I acted like i'd...       125
# 5571       0                         Rofl. Its true to its name        26
#
#       num_word  num_sent
# 0           24         2
# 1            8         2
# 2           37         2
# 3           13         1
# 4           15         1
# ...        ...       ...
# 5567        35         4
# 5568         9         1
# 5569        15         2
# 5570        27         1
# 5571         7         2
#
# [5164 rows x 5 columns]

# %%
df.describe()
# Out:
#             target     num_char     num_word     num_sent
# count  5164.000000  5164.000000  5164.000000  5164.000000
# mean      0.126452    77.424864    17.943067     1.926220
# std       0.332391    57.196505    12.802325     1.306051
# min       0.000000     2.000000     1.000000     1.000000
# 25%       0.000000    35.000000     9.000000     1.000000
# 50%       0.000000    59.000000    14.000000     1.000000
# 75%       0.000000   114.000000    26.000000     2.000000
# max       1.000000   910.000000   196.000000    16.000000

# %%
#ham
df[df["target"]==0].describe()
# Out:
#        target     num_char     num_word     num_sent
# count  4511.0  4511.000000  4511.000000  4511.000000
# mean      0.0    68.677898    16.536245     1.775438
# std       0.0    54.839732    12.838860     1.206185
# min       0.0     2.000000     1.000000     1.000000
# 25%       0.0    33.000000     8.000000     1.000000
# 50%       0.0    51.000000    13.000000     1.000000
# 75%       0.0    88.000000    21.000000     2.000000
# max       0.0   910.000000   196.000000    16.000000

# %%
#spam
df[df["target"]==1].describe()
# Out:
#        target    num_char    num_word    num_sent
# count   653.0  653.000000  653.000000  653.000000
# mean      1.0  137.849923   27.661562    2.967841
# std       0.0   30.278090    7.027357    1.483201
# min       1.0   13.000000    2.000000    1.000000
# 25%       1.0  132.000000   25.000000    2.000000
# 50%       1.0  149.000000   29.000000    3.000000
# 75%       1.0  157.000000   32.000000    4.000000
# max       1.0  224.000000   46.000000    8.000000

# %%
import seaborn as sns

# %%
sns.histplot(df[df["target"]==0]["num_char"])
sns.histplot(df[df["target"]==1]["num_char"],color="r")
# Out:
# <AxesSubplot:xlabel='num_char', ylabel='Count'>

# %%
sns.histplot(df[df["target"]==0]["num_word"])
sns.histplot(df[df["target"]==1]["num_word"],color="r")
# Out:
# <AxesSubplot:xlabel='num_word', ylabel='Count'>

# %%
sns.histplot(df[df["target"]==0]["num_sent"])
sns.histplot(df[df["target"]==1]["num_sent"],color="r")
# Out:
# <AxesSubplot:xlabel='num_sent', ylabel='Count'>

# %%
sns.pairplot(df,hue="target")

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # data preproccesing

# %% [markdown]
# * lower case
# *tokaniztion
# *Remove special charachater
# *removing stop word and punctuation
# *steming

# %%
def transform_text(text):
    text=text.lower()# lower case   
    text=nltk.word_tokenize(text)#tokanization
    
    y=[]
    for i in text:
        if i.isalnum():# removing special char
            y.append(i)
            
    text=y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words("english") and i not in string.punctuation:
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    return " ".join(y)

# %%
#import nltk
#nltk.download('all')

# %%
#import nltk
#nltk.download()

# %%
>>> import nltk
>>> nltk.download("stopwords")
# Out:
# [nltk_data] Error loading stopwords: [WinError 10060] A connection
# [nltk_data]     attempt failed because the connected party did not
# [nltk_data]     properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond
# False

# %%
from nltk.corpus import stopwords

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
transform_text("Did you like my presentation on ml ?")
# Out:
# 'like present ml'

# %%
df["text"][2000]
# Out:
# "But i'll b going 2 sch on mon. My sis need 2 take smth."

# %%
df["text"][2]
# Out:
# "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"

# %%
df["text"][5567]
# Out:
# 'This is the 2nd time we have tried 2 contact u. U have won the å£750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate.'

# %%
df["transform_text"]=df["text"].apply(transform_text)
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_11740\733104182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["transform_text"]=df["text"].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_char  \
# 0       0  Go until jurong point, crazy.. Available only ...       111
# 1       0                      Ok lar... Joking wif u oni...        29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3       0  U dun say so early hor... U c already then say...        49
# 4       0  Nah I don't think he goes to usf, he lives aro...        61
#
#    num_word  num_sent                                     transform_text
# 0        24         2  go jurong point crazi avail bugi n great world...
# 1         8         2                              ok lar joke wif u oni
# 2        37         2  free entri 2 wkli comp win fa cup final tkt 21...
# 3        13         1                u dun say earli hor u c alreadi say
# 4        15         1               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color="white")

# %%
 spam_wc=wc.generate(df[df["target"]==1]["transform_text"].str.cat(sep=""))

# %%
plt.imshow(spam_wc)

# %%
 ham_wc=wc.generate(df[df["target"]==0]["transform_text"].str.cat(sep=""))

# %%
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_char  \
# 0       0  Go until jurong point, crazy.. Available only ...       111
# 1       0                      Ok lar... Joking wif u oni...        29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3       0  U dun say so early hor... U c already then say...        49
# 4       0  Nah I don't think he goes to usf, he lives aro...        61
#
#    num_word  num_sent                                     transform_text
# 0        24         2  go jurong point crazi avail bugi n great world...
# 1         8         2                              ok lar joke wif u oni
# 2        37         2  free entri 2 wkli comp win fa cup final tkt 21...
# 3        13         1                u dun say earli hor u c alreadi say
# 4        15         1               nah think goe usf live around though

# %%
spam_corpus=[]
for msg in df[df["target"]==1]["transform_text"].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9936

# %%
from collections import Counter
pd.DataFrame(Counter(spam_corpus).most_common(30))
# Out:
#           0    1
# 0      call  320
# 1      free  191
# 2         2  155
# 3       txt  141
# 4      text  122
# 5         u  119
# 6        ur  119
# 7     mobil  114
# 8      stop  104
# 9     repli  103
# 10    claim   98
# 11        4   97
# 12    prize   82
# 13      get   74
# 14      new   64
# 15   servic   64
# 16     tone   63
# 17     send   60
# 18   urgent   57
# 19    nokia   57
# 20  contact   56
# 21    award   55
# 22    phone   52
# 23     cash   51
# 24    pleas   51
# 25     week   49
# 26      win   48
# 27        c   45
# 28  collect   45
# 29      min   45

# %%
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation="vertical")
plt.show()
# Out:
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ham_corpus=[]
for msg in df[df["target"]==0]["transform_text"].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 34382

# %%
from collections import Counter
pd.DataFrame(Counter(ham_corpus).most_common(30))
# Out:
#         0    1
# 0       u  865
# 1      go  400
# 2     get  340
# 3       2  280
# 4    come  271
# 5      lt  238
# 6     got  233
# 7    know  233
# 8    like  229
# 9    call  229
# 10     ok  213
# 11   time  213
# 12   love  212
# 13   want  207
# 14   good  206
# 15     ur  192
# 16    day  185
# 17   need  168
# 18    one  163
# 19    lor  159
# 20      4  154
# 21   home  149
# 22  think  147
# 23    see  144
# 24   take  141
# 25  still  141
# 26     da  136
# 27   tell  129
# 28   make  126
# 29    say  124

# %%
sns.barplot(pd.DataFrame(Counter(ham_corpus).most_common(30))[0],pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation="vertical")
plt.show()
# Out:
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 4.Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv=CountVectorizer()
tfidf=TfidfVectorizer()

# %%
x=tfidf.fit_transform(df["transform_text"]).toarray()

# %%
x.shape
# Out:
# (5164, 6593)

# %%
y=df["target"].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(x_train,y_train)
y_pred1=gnb.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred1)*100)
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1)*100)
# Out:
# 85.47918683446272
# [[779 124]
#  [ 26 104]]
# 45.614035087719294

# %%
mnb.fit(x_train,y_train)
y_pred2=mnb.predict(x_test)
print(accuracy_score(y_test,y_pred2)*100)
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2)*100)
# Out:
# 95.54695062923524
# [[903   0]
#  [ 46  84]]
# 100.0

# %%
bnb.fit(x_train,y_train)
y_pred3=bnb.predict(x_test)
print(accuracy_score(y_test,y_pred3)*100)
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3)*100)
# Out:
# 96.90222652468539
# [[900   3]
#  [ 29 101]]
# 97.11538461538461

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\shind\anaconda3\lib\site-packages (0.0.post1)Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Creating pipline

# %%
import pickle
pickle.dump(tfidf,open("vectorizer.pkl","wb"))
pickle.dump(mnb,open("model.pkl","wb"))
